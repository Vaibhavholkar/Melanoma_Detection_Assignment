# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/drive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/drive/MyDrive/Cancer Detection/Train")
data_dir_test = pathlib.Path('/content/drive/MyDrive/Cancer Detection/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'training',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'validation',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(9):
  plt.subplot(3, 3, i + 1)
  image = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)
### your code goes here, you can use training or validation data to visualize

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      2432
#
#  conv2d_1 (Conv2D)           (None, 180, 180, 32)      25632
#
#  max_pooling2d (MaxPooling2  (None, 90, 90, 32)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 90, 90, 32)        25632
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 45, 45, 64)        51264
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 64)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 22, 22, 64)        102464
#
#  max_pooling2d_3 (MaxPoolin  (None, 11, 11, 64)        0
#  g2D)
#
#  dropout (Dropout)           (None, 11, 11, 64)        0
#
#  flatten (Flatten)           (None, 7744)              0
#
#  dense (Dense)               (None, 9)                 69705
#
# =================================================================
# Total params: 277129 (1.06 MB)
# Trainable params: 277129 (1.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 56/56 [==============================] - 360s 1s/step - loss: 2.0636 - accuracy: 0.2093 - val_loss: 2.0015 - val_accuracy: 0.1924
# Epoch 2/30
# 56/56 [==============================] - 5s 92ms/step - loss: 2.0066 - accuracy: 0.2037 - val_loss: 2.0352 - val_accuracy: 0.1499
# Epoch 3/30
# 56/56 [==============================] - 5s 91ms/step - loss: 1.9603 - accuracy: 0.2316 - val_loss: 1.9056 - val_accuracy: 0.2752
# Epoch 4/30
# 56/56 [==============================] - 5s 93ms/step - loss: 1.8480 - accuracy: 0.3008 - val_loss: 1.7500 - val_accuracy: 0.3311
# Epoch 5/30
# 56/56 [==============================] - 5s 91ms/step - loss: 1.8672 - accuracy: 0.3030 - val_loss: 1.7389 - val_accuracy: 0.3468
# Epoch 6/30
# 56/56 [==============================] - 5s 93ms/step - loss: 1.6756 - accuracy: 0.3850 - val_loss: 1.7120 - val_accuracy: 0.4004
# Epoch 7/30
# 56/56 [==============================] - 5s 90ms/step - loss: 1.6159 - accuracy: 0.4146 - val_loss: 1.7736 - val_accuracy: 0.3468
# Epoch 8/30
# 56/56 [==============================] - 5s 91ms/step - loss: 1.5813 - accuracy: 0.4319 - val_loss: 1.5460 - val_accuracy: 0.4474
# Epoch 9/30
# 56/56 [==============================] - 5s 90ms/step - loss: 1.5261 - accuracy: 0.4492 - val_loss: 1.4896 - val_accuracy: 0.4698
# Epoch 10/30
# 56/56 [==============================] - 5s 90ms/step - loss: 1.5078 - accuracy: 0.4492 - val_loss: 1.8525 - val_accuracy: 0.4049
# Epoch 11/30
# 56/56 [==============================] - 5s 90ms/step - loss: 1.5151 - accuracy: 0.4593 - val_loss: 1.5015 - val_accuracy: 0.4631
# Epoch 12/30
# 56/56 [==============================] - 5s 90ms/step - loss: 1.3880 - accuracy: 0.4994 - val_loss: 1.4151 - val_accuracy: 0.5213
# Epoch 13/30
# 56/56 [==============================] - 5s 91ms/step - loss: 1.3421 - accuracy: 0.5206 - val_loss: 1.4389 - val_accuracy: 0.4922
# Epoch 14/30
# 56/56 [==============================] - 5s 89ms/step - loss: 1.2515 - accuracy: 0.5508 - val_loss: 1.4674 - val_accuracy: 0.5123
# Epoch 15/30
# 56/56 [==============================] - 5s 90ms/step - loss: 1.2431 - accuracy: 0.5541 - val_loss: 1.5496 - val_accuracy: 0.4631
# Epoch 16/30
# 56/56 [==============================] - 5s 90ms/step - loss: 1.1731 - accuracy: 0.5731 - val_loss: 1.6684 - val_accuracy: 0.4541
# Epoch 17/30
# 56/56 [==============================] - 5s 90ms/step - loss: 1.1676 - accuracy: 0.5770 - val_loss: 1.6899 - val_accuracy: 0.4989
# Epoch 18/30
# 56/56 [==============================] - 5s 91ms/step - loss: 1.0221 - accuracy: 0.6356 - val_loss: 1.5489 - val_accuracy: 0.5324
# Epoch 19/30
# 56/56 [==============================] - 5s 90ms/step - loss: 0.9389 - accuracy: 0.6613 - val_loss: 1.7190 - val_accuracy: 0.4765
# Epoch 20/30
# 56/56 [==============================] - 5s 90ms/step - loss: 0.8743 - accuracy: 0.6836 - val_loss: 1.6677 - val_accuracy: 0.4922
# Epoch 21/30
# 56/56 [==============================] - 5s 91ms/step - loss: 0.7809 - accuracy: 0.7260 - val_loss: 1.7548 - val_accuracy: 0.5011
# Epoch 22/30
# 56/56 [==============================] - 5s 89ms/step - loss: 0.7567 - accuracy: 0.7282 - val_loss: 1.9665 - val_accuracy: 0.4720
# Epoch 23/30
# 56/56 [==============================] - 5s 91ms/step - loss: 0.6991 - accuracy: 0.7461 - val_loss: 1.9567 - val_accuracy: 0.5190
# Epoch 24/30
# 56/56 [==============================] - 5s 90ms/step - loss: 0.6399 - accuracy: 0.7628 - val_loss: 2.0459 - val_accuracy: 0.4362
# Epoch 25/30
# 56/56 [==============================] - 5s 91ms/step - loss: 0.5821 - accuracy: 0.7762 - val_loss: 2.0523 - val_accuracy: 0.5056
# Epoch 26/30
# 56/56 [==============================] - 5s 90ms/step - loss: 0.5738 - accuracy: 0.7924 - val_loss: 2.0824 - val_accuracy: 0.5034
# Epoch 27/30
# 56/56 [==============================] - 5s 91ms/step - loss: 0.4849 - accuracy: 0.8276 - val_loss: 2.1908 - val_accuracy: 0.5101
# Epoch 28/30
# 56/56 [==============================] - 5s 90ms/step - loss: 0.4393 - accuracy: 0.8376 - val_loss: 2.2588 - val_accuracy: 0.5190
# Epoch 29/30
# 56/56 [==============================] - 5s 91ms/step - loss: 0.4373 - accuracy: 0.8382 - val_loss: 2.4488 - val_accuracy: 0.4564
# Epoch 30/30
# 56/56 [==============================] - 5s 90ms/step - loss: 0.4348 - accuracy: 0.8398 - val_loss: 2.5579 - val_accuracy: 0.5213

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# **Finding on the first base model**
#
# - The model is overfitting because we can also see difference in loss functions in training & test around the 10-11th epoch
#
# - The accuracy is just around 75-80% because there are enough features to remember the pattern.
#
# - But again, it's too early to comment on the overfitting & underfitting debate

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
data_augument = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.

plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augument(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ data_augument,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))

])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compiling the model

# %%
### Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs=30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 10s 115ms/step - loss: 2.0603 - accuracy: 0.2037 - val_loss: 2.0336 - val_accuracy: 0.1946
# Epoch 2/30
# 56/56 [==============================] - 6s 105ms/step - loss: 2.0097 - accuracy: 0.2121 - val_loss: 1.9419 - val_accuracy: 0.3221
# Epoch 3/30
# 56/56 [==============================] - 6s 102ms/step - loss: 1.9544 - accuracy: 0.2595 - val_loss: 2.0121 - val_accuracy: 0.2327
# Epoch 4/30
# 56/56 [==============================] - 6s 102ms/step - loss: 1.8752 - accuracy: 0.2852 - val_loss: 1.8507 - val_accuracy: 0.2998
# Epoch 5/30
# 56/56 [==============================] - 6s 104ms/step - loss: 1.8512 - accuracy: 0.3114 - val_loss: 1.7876 - val_accuracy: 0.3132
# Epoch 6/30
# 56/56 [==============================] - 6s 102ms/step - loss: 1.7538 - accuracy: 0.3588 - val_loss: 1.6636 - val_accuracy: 0.4183
# Epoch 7/30
# 56/56 [==============================] - 6s 104ms/step - loss: 1.6674 - accuracy: 0.3945 - val_loss: 1.6426 - val_accuracy: 0.4161
# Epoch 8/30
# 56/56 [==============================] - 6s 103ms/step - loss: 1.5991 - accuracy: 0.4247 - val_loss: 1.5729 - val_accuracy: 0.4340
# Epoch 9/30
# 56/56 [==============================] - 6s 103ms/step - loss: 1.6083 - accuracy: 0.4141 - val_loss: 1.5671 - val_accuracy: 0.4452
# Epoch 10/30
# 56/56 [==============================] - 6s 102ms/step - loss: 1.6175 - accuracy: 0.4113 - val_loss: 1.5788 - val_accuracy: 0.4340
# Epoch 11/30
# 56/56 [==============================] - 6s 104ms/step - loss: 1.5491 - accuracy: 0.4342 - val_loss: 1.6366 - val_accuracy: 0.3960
# Epoch 12/30
# 56/56 [==============================] - 6s 102ms/step - loss: 1.6036 - accuracy: 0.4208 - val_loss: 1.5471 - val_accuracy: 0.4407
# Epoch 13/30
# 56/56 [==============================] - 6s 102ms/step - loss: 1.5724 - accuracy: 0.4241 - val_loss: 1.5499 - val_accuracy: 0.4452
# Epoch 14/30
# 56/56 [==============================] - 6s 104ms/step - loss: 1.5281 - accuracy: 0.4414 - val_loss: 1.5417 - val_accuracy: 0.4407
# Epoch 15/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.5277 - accuracy: 0.4459 - val_loss: 1.5854 - val_accuracy: 0.4139
# Epoch 16/30
# 56/56 [==============================] - 6s 104ms/step - loss: 1.4980 - accuracy: 0.4604 - val_loss: 1.5433 - val_accuracy: 0.4519
# Epoch 17/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.5172 - accuracy: 0.4509 - val_loss: 1.4704 - val_accuracy: 0.4832
# Epoch 18/30
# 56/56 [==============================] - 6s 104ms/step - loss: 1.4760 - accuracy: 0.4721 - val_loss: 1.5010 - val_accuracy: 0.4743
# Epoch 19/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.4763 - accuracy: 0.4810 - val_loss: 1.5058 - val_accuracy: 0.4586
# Epoch 20/30
# 56/56 [==============================] - 6s 103ms/step - loss: 1.4586 - accuracy: 0.4833 - val_loss: 1.6147 - val_accuracy: 0.4362
# Epoch 21/30
# 56/56 [==============================] - 6s 103ms/step - loss: 1.4246 - accuracy: 0.4827 - val_loss: 1.4985 - val_accuracy: 0.4676
# Epoch 22/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.4138 - accuracy: 0.4939 - val_loss: 1.4703 - val_accuracy: 0.4877
# Epoch 23/30
# 56/56 [==============================] - 6s 103ms/step - loss: 1.4146 - accuracy: 0.4894 - val_loss: 1.4455 - val_accuracy: 0.4676
# Epoch 24/30
# 56/56 [==============================] - 6s 103ms/step - loss: 1.3897 - accuracy: 0.5106 - val_loss: 1.4429 - val_accuracy: 0.4855
# Epoch 25/30
# 56/56 [==============================] - 6s 103ms/step - loss: 1.3607 - accuracy: 0.5140 - val_loss: 1.5318 - val_accuracy: 0.4855
# Epoch 26/30
# 56/56 [==============================] - 6s 104ms/step - loss: 1.3454 - accuracy: 0.5201 - val_loss: 1.3966 - val_accuracy: 0.5101
# Epoch 27/30
# 56/56 [==============================] - 6s 104ms/step - loss: 1.3339 - accuracy: 0.5112 - val_loss: 1.4918 - val_accuracy: 0.5078
# Epoch 28/30
# 56/56 [==============================] - 6s 103ms/step - loss: 1.3440 - accuracy: 0.5212 - val_loss: 1.4158 - val_accuracy: 0.4855
# Epoch 29/30
# 56/56 [==============================] - 6s 104ms/step - loss: 1.2979 - accuracy: 0.5368 - val_loss: 1.4717 - val_accuracy: 0.5078
# Epoch 30/30
# 56/56 [==============================] - 6s 103ms/step - loss: 1.3083 - accuracy: 0.5374 - val_loss: 1.3999 - val_accuracy: 0.4922

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# **Finding from Second Model**
#
# - There is no improvement in accuracy but we can definitely see the overfitting problem has solved due to data augmentation
#
# - We can increase the epochs to increase the accuracy so it's too early for judgement

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
##
path_list=[]
lesion_list=[]
for i in class_names:

    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 1     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 2     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 3     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 4     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 2235  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 2236  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 2237  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 2238  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 1     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 2     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 3     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 4     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 2235  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 2236  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 2237  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 2238  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %% [markdown]
# Answer-1 :- **squamous cell carcinoma** has least number of samples
#
# Answer-2:- **actinic keratosis and dermatofibroma** have proportionate number of classes.
# **melanoma and pigmented benign keratosis** have proprtionate number of classes

# %%
class_names
# Out:
# ['actinic keratosis',
#  'basal cell carcinoma',
#  'dermatofibroma',
#  'melanoma',
#  'nevus',
#  'pigmented benign keratosis',
#  'seborrheic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion']

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.2)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.25.2)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
#path_to_training_dataset="/content/drive/MyDrive/Cancer Detection /Train"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline("/content/drive/MyDrive/Cancer Detection/Train",save_format='jpg')
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/Cancer Detection/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x792B700D17B0>: 100%|██████████| 500/500 [00:57<00:00,  8.75 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/Cancer Detection/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x792B10468940>: 100%|██████████| 500/500 [00:43<00:00, 11.46 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/Cancer Detection/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x792B10697460>: 100%|██████████| 500/500 [00:44<00:00, 11.30 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/Cancer Detection/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x792B104535E0>: 100%|██████████| 500/500 [00:36<00:00, 13.77 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/Cancer Detection/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x792B1031DF60>: 100%|██████████| 500/500 [00:37<00:00, 13.37 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/Cancer Detection/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x792B10598EB0>: 100%|██████████| 500/500 [00:42<00:00, 11.84 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/Cancer Detection/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x792B10569C00>: 100%|██████████| 500/500 [00:42<00:00, 11.66 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/Cancer Detection/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x792B3212DC30>: 100%|██████████| 500/500 [00:35<00:00, 13.98 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/drive/MyDrive/Cancer Detection/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x792B70205750>: 100%|██████████| 500/500 [00:39<00:00, 12.58 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
data_dir_train1 = pathlib.Path("/content/drive/MyDrive/Cancer Detection/Train/output")
image_count_train1 = len(list(data_dir_train1.glob('*/*.jpg')))
print(image_count_train1)
# Out:
# 4500

# %%
##
for i in class_names:

    for j in data_dir_train1.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
new_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
new_df
# Out:
#                                                    Path              Label
# 0     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 1     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 2     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 3     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# 4     /content/drive/MyDrive/Cancer Detection/Train/...  actinic keratosis
# ...                                                 ...                ...
# 6734  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 6735  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 6736  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 6737  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
# 6738  /content/drive/MyDrive/Cancer Detection/Train/...    vascular lesion
#
# [6739 rows x 2 columns]

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    1385
# melanoma                      1305
# basal cell carcinoma          1142
# nevus                         1067
# squamous cell carcinoma        515
# vascular lesion                416
# actinic keratosis              358
# dermatofibroma                 294
# seborrheic keratosis           257
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
import pathlib
#data_dir_train1=pathlib.Path("/content/drive/MyDrive/Cancer Detection /Train/output")
data_dir_train1=pathlib.Path("/content/drive/MyDrive/Cancer Detection/Train")

# %%
data_dir_train1
# Out:
# PosixPath('/content/drive/MyDrive/Cancer Detection/Train')

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
image_count_train1 = len(list(data_dir_train1.glob('*/*.jpg')))
print(image_count_train1)
# Out:
# 2239

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential


data_dir_train1=pathlib.Path("/content/drive/MyDrive/Cancer Detection/Train")
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 10 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 10 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))

])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same',
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## ### Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs =50
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 169/169 [==============================] - 63s 327ms/step - loss: nan - accuracy: 0.0224 - val_loss: nan - val_accuracy: 0.0230
# Epoch 2/50
# 169/169 [==============================] - 48s 277ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 3/50
# 169/169 [==============================] - 46s 266ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 4/50
# 169/169 [==============================] - 48s 274ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 5/50
# 169/169 [==============================] - 45s 256ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 6/50
# 169/169 [==============================] - 44s 253ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 7/50
# 169/169 [==============================] - 46s 260ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 8/50
# 169/169 [==============================] - 44s 255ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 9/50
# 169/169 [==============================] - 47s 267ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 10/50
# 169/169 [==============================] - 44s 253ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 11/50
# 169/169 [==============================] - 45s 256ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 12/50
# 169/169 [==============================] - 45s 255ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 13/50
# 169/169 [==============================] - 44s 254ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 14/50
# 169/169 [==============================] - 46s 263ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 15/50
# 169/169 [==============================] - 44s 252ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 16/50
# 169/169 [==============================] - 46s 263ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 17/50
# 169/169 [==============================] - 44s 250ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 18/50
# 169/169 [==============================] - 44s 254ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 19/50
# 169/169 [==============================] - 44s 252ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 20/50
# 169/169 [==============================] - 47s 272ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 21/50
# 169/169 [==============================] - 44s 252ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 22/50
# 169/169 [==============================] - 47s 267ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 23/50
# 169/169 [==============================] - 44s 253ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 24/50
# 169/169 [==============================] - 45s 260ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 25/50
# 169/169 [==============================] - 44s 255ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 26/50
# 169/169 [==============================] - 48s 274ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 27/50
# 169/169 [==============================] - 44s 255ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 28/50
# 169/169 [==============================] - 47s 270ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 29/50
# 169/169 [==============================] - 47s 272ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 30/50
# 169/169 [==============================] - 46s 262ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 31/50
# 169/169 [==============================] - 44s 253ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 32/50
# 169/169 [==============================] - 47s 271ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 33/50
# 169/169 [==============================] - 45s 260ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 34/50
# 169/169 [==============================] - 47s 272ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 35/50
# 169/169 [==============================] - 44s 253ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 36/50
# 169/169 [==============================] - 45s 257ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 37/50
# 169/169 [==============================] - 44s 254ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 38/50
# 169/169 [==============================] - 46s 261ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 39/50
# 169/169 [==============================] - 44s 251ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 40/50
# 169/169 [==============================] - 46s 266ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 41/50
# 169/169 [==============================] - 44s 253ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 42/50
# 169/169 [==============================] - 44s 254ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 43/50
# 169/169 [==============================] - 48s 268ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 44/50
# 169/169 [==============================] - 44s 254ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 45/50
# 169/169 [==============================] - 46s 257ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 46/50
# 169/169 [==============================] - 45s 257ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 47/50
# 169/169 [==============================] - 47s 266ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 48/50
# 169/169 [==============================] - 43s 248ms/step - loss: nan - accuracy: 0.0154 - val_loss: nan - val_accuracy: 0.0230
# Epoch 49/50
#  10/169 [>.............................] - ETA: 28s - loss: nan - accuracy: 0.0188

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# - Accuracy on training data has increased by using Augmentor library
#
# - Model is still overfitting
#
# - The problem of overfitting can be solved by add more layer,neurons or adding dropout layers.
#
# - The Model can be further improved by tuning the hyperparameter
